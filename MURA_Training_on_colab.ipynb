# %%
import os
# !wget https://cs.stanford.edu/group/mlgroup/MURA-v1.1.zip
from google.colab import files
# Out:
# --2021-12-19 15:06:26--  https://cs.stanford.edu/group/mlgroup/MURA-v1.1.zip
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3380245855 (3.1G) [application/zip]
# Saving to: ‘MURA-v1.1.zip.1’
#
# MURA-v1.1.zip.1     100%[===================>]   3.15G  55.4MB/s    in 62s
#
# 2021-12-19 15:07:29 (51.7 MB/s) - ‘MURA-v1.1.zip.1’ saved [3380245855/3380245855]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/MURA-v1.1.zip /content

# %%
# !unzip MURA-v1.1.zip
# Out:
# Archive:  MURA-v1.1.zip
# replace MURA-v1.1/train_labeled_studies.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
########################################
# ENTER THE NAME OF THE DIRECTORY OF YOUR BONE HERE:
# One of the seven listed below:
"""
XR_ELBOW
XR_FINGER
XR_FOREARM
XR_HAND
XR_HUMERUS
XR_SHOULDER
XR_WRIST
""" 
training_bone = 'XR_HUMERUS'
########################################

# %%
saved_models_path = "/content/drive/MyDrive/saved_models_"+training_bone
os.makedirs(saved_models_path, exist_ok=True)
os.makedirs("valid", exist_ok=True)
os.makedirs("train", exist_ok=True)
os.makedirs("log", exist_ok=True)
os.makedirs("figures", exist_ok=True)

# %%
os.system("cp -r /content/MURA-v1.1/train/"+training_bone+" train/")
os.system("cp -r /content/MURA-v1.1/valid/"+training_bone+" valid/")
# Out:
# 0

# %%
# !wget 'https://raw.githubusercontent.com/AhmedSamySaad/MAC/master/densenet.py' -O densenet.py
# !wget 'https://raw.githubusercontent.com/AhmedSamySaad/MAC/master/data_loader.py' -O data_loader.py
# Out:
# --2021-12-19 15:09:25--  https://raw.githubusercontent.com/AhmedSamySaad/MAC/master/densenet.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6999 (6.8K) [text/plain]
# Saving to: ‘densenet.py’
#
# densenet.py         100%[===================>]   6.83K  --.-KB/s    in 0s
#
# 2021-12-19 15:09:26 (55.2 MB/s) - ‘densenet.py’ saved [6999/6999]
#
# --2021-12-19 15:09:26--  https://raw.githubusercontent.com/AhmedSamySaad/MAC/master/data_loader.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2097 (2.0K) [text/plain]
# Saving to: ‘data_loader.py’
#
# data_loader.py      100%[===================>]   2.05K  --.-KB/s    in 0s
#
# 2021-12-19 15:09:26 (22.3 MB/s) - ‘data_loader.py’ saved [2097/2097]

# %%
from __future__ import print_function

import os
import time
import datetime
import random
import json
import argparse
import densenet
import numpy as np
import keras.backend as K

from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils

import data_loader





def run_MURA(batch_size, nb_epoch, depth, nb_dense_block, nb_filter, growth_rate, dropout_rate, learning_rate, weight_decay, plot_architecture):
    """
    Run MURA experiments

    :parameter batch_size: int -- batch size
    :parameter nb_epoch: int -- number of training epochs
    :parameter depth: int -- network depth
    :parameter nb_dense_block: int -- number of dense blocks
    :parameter nb_filter: int -- initial number of conv filter
    :parameter growth_rate: int -- number of new filters added by conv layers
    :parameter dropout_rate: float -- dropout rate
    :parameter learning_rate: float -- learning rate
    :parameter weight_decay: float -- weight decay
    :parameter plot_architecture: bool -- whether to plot network architecture

    """

    ###################
    # Data processing #
    ###################

    
    im_size = 320   #Test modification parameters size root_path nb_epoch nb_dense_block         
    X_train_path, Y_train = data_loader.load_path(root_path = './train/'+training_bone,size = im_size)  
    X_valid_path, Y_valid = data_loader.load_path(root_path = './valid/'+training_bone, size = im_size)  

    X_valid = data_loader.load_image(X_valid_path,im_size)  #Load verification set ahead of time
    Y_valid = np.asarray(Y_valid)
    nb_classes = 1                                
    img_dim = (im_size,im_size,1)                 #Plus the last dimension, type is tuple

    
    ###################
    # Construct model #
    ###################

    model = densenet.DenseNet(nb_classes, img_dim, depth, nb_dense_block, growth_rate, nb_filter, dropout_rate=dropout_rate, weight_decay=weight_decay)
    model.summary()
    # Build optimizer
    opt = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy"])

    if plot_architecture:
        from keras.utils import plot_model
        plot_model(model, to_file='./figures/densenet_archi.png', show_shapes=True)

    ####################
    # Network training #
    ####################

    print("Start Training")

    list_train_loss = []
    list_valid_loss = []
    list_learning_rate = []
    best_record = [100,0,100,100] #Recording optimal [verification set loss function value, accuracy rate, training set data set loss difference,acc difference]
    start_time = datetime.datetime.now()
    for e in range(nb_epoch):

        if e == int(0.25 * nb_epoch):
            K.set_value(model.optimizer.lr, np.float32(learning_rate / 10.))

        if e == int(0.5 * nb_epoch):
            K.set_value(model.optimizer.lr, np.float32(learning_rate / 50.))

        if e == int(0.75 * nb_epoch):
            K.set_value(model.optimizer.lr, np.float32(learning_rate / 100.))


        split_size = batch_size
        num_splits = len(X_train_path) / split_size

        arr_all = np.arange(len(X_train_path)).astype(int)
        random.shuffle(arr_all)                 #Randomly disrupted index order
        arr_splits = np.array_split(arr_all, num_splits)

        l_train_loss = []
        batch_train_loss = []
        start = datetime.datetime.now()

        for i,batch_idx in enumerate(arr_splits):


            X_batch_path,Y_batch = [],[]
            for idx in batch_idx:
                X_batch_path.append(X_train_path[idx])
                Y_batch.append(Y_train[idx])
            X_batch = data_loader.load_image(Path = X_batch_path, size =im_size)
            Y_batch = np.asarray(Y_batch)
            train_logloss, train_acc = model.train_on_batch(X_batch, Y_batch)

            l_train_loss.append([train_logloss, train_acc])
            batch_train_loss.append([train_logloss, train_acc])
            if i %100 == 0:
                loss_1, acc_1 = np.mean(np.array(l_train_loss), 0)
                loss_2, acc_2 = np.mean(np.array(batch_train_loss), 0)
                batch_train_loss = []           #Current 100 batch loss function and accuracy
                print ('[Epoch {}/{}] [Batch {}/{}] [Time: {}] [all_batchs--> train_epoch_logloss: {:.5f}, train_epoch_acc:{:.5f}] '.format(e+1,nb_epoch,i, len(arr_splits),datetime.datetime.now() - start,loss_1,acc_1), '[this_100_batchs-->train_batchs_logloss: {:.5f}, train_batchs_acc:{:.5f}]'.format(loss_2, acc_2))

        # Run verification set
        valid_logloss, valid_acc = model.evaluate(X_valid, Y_valid, verbose=0, batch_size=64)
        list_train_loss.append(np.mean(np.array(l_train_loss), 0).tolist())
        list_valid_loss.append([valid_logloss, valid_acc])
        list_learning_rate.append(float(K.get_value(model.optimizer.lr)))
        # to convert numpy array to json serializable
        print('[Epoch %s/%s] [Time: %s, Total_time: %s]' % (e + 1, nb_epoch, datetime.datetime.now() - start, datetime.datetime.now() - start_time),end = '')
        print('[train_loss_and_acc:{:.5f} {:.5f}] [valid_loss_acc:{:.5f} {:.5f}]'.format(list_train_loss[-1][0], list_train_loss[-1][1],list_valid_loss[-1][0],list_valid_loss[-1][1]))


        d_log = {}
        d_log["batch_size"] = batch_size
        d_log["nb_epoch"] = nb_epoch
        d_log["optimizer"] = opt.get_config()
        d_log["train_loss"] = list_train_loss
        d_log["valid_loss"] = list_valid_loss
        d_log["learning_rate"] = list_learning_rate

        json_file = os.path.join('./log/experiment_log_MURA.json')
        with open(json_file, 'w') as fp:
            json.dump(str(d_log), fp, indent=4, sort_keys=True)



        record = [valid_logloss,valid_acc,abs(valid_logloss-list_train_loss[-1][0]),abs(valid_acc-list_train_loss[-1][1]),]
        if ((record[0]<=best_record[0]) &(record[1]>=best_record[1])) :
            if e <= int(0.25 * nb_epoch)|(record[2]<=best_record[2])&(record[3]<=best_record[3]):#Add a difference judgment after a quarter epoch
                best_record=record                      #Record the smallest [validation set loss function value, accuracy rate, training set data loss difference, acc difference]
                print('saving the best model:epoch',e+1,best_record)
                best_model_weight= saved_models_path+'/best_MURA_model@epochs{}.h5'.format(e+1)
                model.save(best_model_weight)
                # !cp /content/save_models/best_model_weight /content/drive/MyDrive/saved_model
                # files.download(best_model_weight)
        weight_file= saved_models_path+'/MURA_model@epochs{}.h5'.format(e+1)
        model.save(weight_file)
        # os.system("cp /content/save_models/weight_file"+ +" /content/drive/MyDrive/saved_model")
        # !cp /content/save_models/weight_file /content/drive/MyDrive/saved_model
        # files.download(weight_file)


# print("Network configuration:")
# parms = ["batch_size", "nb_epoch", "depth", "nb_dense_block", "nb_filter", "growth_rate", "dropout_rate", "learning_rate", "weight_decay", "plot_architecture"]
# for name in parms:
# for name, value in parser.parse_args()._get_kwargs():
    # print(name, value)


# run_MURA(batch_size= 1, nb_epoch= 3, depth= 22, nb_dense_block= 4, nb_filter= 16, growth_rate= 12, dropout_rate= 0.2, learning_rate=1E-3, weight_decay=1E-4, plot_architecture= False)
run_MURA(batch_size= 8, nb_epoch= 52, depth= 22, nb_dense_block= 4, nb_filter= 16, growth_rate= 12, dropout_rate= 0.2, learning_rate=1E-3, weight_decay=1E-4, plot_architecture= False)
# Out:
# 1272
# 288
# Model: "DenseNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 320, 320, 1  0           []
#                                 )]
#
#  initial_conv2D (Conv2D)        (None, 160, 160, 16  784         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_168 (Batch  (None, 160, 160, 16  64         ['initial_conv2D[0][0]']
#  Normalization)                 )
#
#  activation_168 (Activation)    (None, 160, 160, 16  0           ['batch_normalization_168[0][0]']
#                                 )
#
#  conv2d_167 (Conv2D)            (None, 160, 160, 12  192         ['activation_168[0][0]']
#                                 )
#
#  batch_normalization_169 (Batch  (None, 160, 160, 12  48         ['conv2d_167[0][0]']
#  Normalization)                 )
#
#  activation_169 (Activation)    (None, 160, 160, 12  0           ['batch_normalization_169[0][0]']
#                                 )
#
#  conv2d_168 (Conv2D)            (None, 160, 160, 12  1296        ['activation_169[0][0]']
#                                 )
#
#  dropout_85 (Dropout)           (None, 160, 160, 12  0           ['conv2d_168[0][0]']
#                                 )
#
#  concatenate_82 (Concatenate)   (None, 160, 160, 28  0           ['initial_conv2D[0][0]',
#                                 )                                 'dropout_85[0][0]']
#
#  batch_normalization_170 (Batch  (None, 160, 160, 28  112        ['concatenate_82[0][0]']
#  Normalization)                 )
#
#  activation_170 (Activation)    (None, 160, 160, 28  0           ['batch_normalization_170[0][0]']
#                                 )
#
#  conv2d_169 (Conv2D)            (None, 160, 160, 12  336         ['activation_170[0][0]']
#                                 )
#
#  batch_normalization_171 (Batch  (None, 160, 160, 12  48         ['conv2d_169[0][0]']
#  Normalization)                 )
#
#  activation_171 (Activation)    (None, 160, 160, 12  0           ['batch_normalization_171[0][0]']
#                                 )
#
#  conv2d_170 (Conv2D)            (None, 160, 160, 12  1296        ['activation_171[0][0]']
#                                 )
#
#  dropout_86 (Dropout)           (None, 160, 160, 12  0           ['conv2d_170[0][0]']
#                                 )
#
#  concatenate_83 (Concatenate)   (None, 160, 160, 40  0           ['initial_conv2D[0][0]',
#                                 )                                 'dropout_85[0][0]',
#                                                                   'dropout_86[0][0]']
#
#  batch_normalization_172 (Batch  (None, 160, 160, 40  160        ['concatenate_83[0][0]']
#  Normalization)                 )
#
#  activation_172 (Activation)    (None, 160, 160, 40  0           ['batch_normalization_172[0][0]']
#                                 )
#
#  conv2d_171 (Conv2D)            (None, 160, 160, 12  480         ['activation_172[0][0]']
#                                 )
#
#  batch_normalization_173 (Batch  (None, 160, 160, 12  48         ['conv2d_171[0][0]']
#  Normalization)                 )
#
#  activation_173 (Activation)    (None, 160, 160, 12  0           ['batch_normalization_173[0][0]']
#                                 )
#
#  conv2d_172 (Conv2D)            (None, 160, 160, 12  1296        ['activation_173[0][0]']
#                                 )
#
#  dropout_87 (Dropout)           (None, 160, 160, 12  0           ['conv2d_172[0][0]']
#                                 )
#
#  concatenate_84 (Concatenate)   (None, 160, 160, 52  0           ['initial_conv2D[0][0]',
#                                 )                                 'dropout_85[0][0]',
#                                                                   'dropout_86[0][0]',
#                                                                   'dropout_87[0][0]']
#
#  batch_normalization_174 (Batch  (None, 160, 160, 52  208        ['concatenate_84[0][0]']
#  Normalization)                 )
#
#  activation_174 (Activation)    (None, 160, 160, 52  0           ['batch_normalization_174[0][0]']
#                                 )
#
#  conv2d_173 (Conv2D)            (None, 160, 160, 12  624         ['activation_174[0][0]']
#                                 )
#
#  batch_normalization_175 (Batch  (None, 160, 160, 12  48         ['conv2d_173[0][0]']
#  Normalization)                 )
#
#  activation_175 (Activation)    (None, 160, 160, 12  0           ['batch_normalization_175[0][0]']
#                                 )
#
#  conv2d_174 (Conv2D)            (None, 160, 160, 12  1296        ['activation_175[0][0]']
#                                 )
#
#  dropout_88 (Dropout)           (None, 160, 160, 12  0           ['conv2d_174[0][0]']
#                                 )
#
#  concatenate_85 (Concatenate)   (None, 160, 160, 64  0           ['initial_conv2D[0][0]',
#                                 )                                 'dropout_85[0][0]',
#                                                                   'dropout_86[0][0]',
#                                                                   'dropout_87[0][0]',
#                                                                   'dropout_88[0][0]']
#
#  batch_normalization_176 (Batch  (None, 160, 160, 64  256        ['concatenate_85[0][0]']
#  Normalization)                 )
#
#  activation_176 (Activation)    (None, 160, 160, 64  0           ['batch_normalization_176[0][0]']
#                                 )
#
#  conv2d_175 (Conv2D)            (None, 160, 160, 12  768         ['activation_176[0][0]']
#                                 )
#
#  batch_normalization_177 (Batch  (None, 160, 160, 12  48         ['conv2d_175[0][0]']
#  Normalization)                 )
#
#  activation_177 (Activation)    (None, 160, 160, 12  0           ['batch_normalization_177[0][0]']
#                                 )
#
#  conv2d_176 (Conv2D)            (None, 160, 160, 12  1296        ['activation_177[0][0]']
#                                 )
#
#  dropout_89 (Dropout)           (None, 160, 160, 12  0           ['conv2d_176[0][0]']
#                                 )
#
#  concatenate_86 (Concatenate)   (None, 160, 160, 76  0           ['initial_conv2D[0][0]',
#                                 )                                 'dropout_85[0][0]',
#                                                                   'dropout_86[0][0]',
#                                                                   'dropout_87[0][0]',
#                                                                   'dropout_88[0][0]',
#                                                                   'dropout_89[0][0]']
#
#  batch_normalization_178 (Batch  (None, 160, 160, 76  304        ['concatenate_86[0][0]']
#  Normalization)                 )
#
#  activation_178 (Activation)    (None, 160, 160, 76  0           ['batch_normalization_178[0][0]']
#                                 )
#
#  conv2d_177 (Conv2D)            (None, 160, 160, 12  912         ['activation_178[0][0]']
#                                 )
#
#  batch_normalization_179 (Batch  (None, 160, 160, 12  48         ['conv2d_177[0][0]']
#  Normalization)                 )
#
#  activation_179 (Activation)    (None, 160, 160, 12  0           ['batch_normalization_179[0][0]']
#                                 )
#
#  conv2d_178 (Conv2D)            (None, 160, 160, 12  1296        ['activation_179[0][0]']
#                                 )
#
#  dropout_90 (Dropout)           (None, 160, 160, 12  0           ['conv2d_178[0][0]']
#                                 )
#
#  concatenate_87 (Concatenate)   (None, 160, 160, 88  0           ['initial_conv2D[0][0]',
#                                 )                                 'dropout_85[0][0]',
#                                                                   'dropout_86[0][0]',
#                                                                   'dropout_87[0][0]',
#                                                                   'dropout_88[0][0]',
#                                                                   'dropout_89[0][0]',
#                                                                   'dropout_90[0][0]']
#
#  batch_normalization_180 (Batch  (None, 160, 160, 88  352        ['concatenate_87[0][0]']
#  Normalization)                 )
#
#  activation_180 (Activation)    (None, 160, 160, 88  0           ['batch_normalization_180[0][0]']
#                                 )
#
#  conv2d_179 (Conv2D)            (None, 160, 160, 88  7744        ['activation_180[0][0]']
#                                 )
#
#  dropout_91 (Dropout)           (None, 160, 160, 88  0           ['conv2d_179[0][0]']
#                                 )
#
#  average_pooling2d_3 (AveragePo  (None, 80, 80, 88)  0           ['dropout_91[0][0]']
#  oling2D)
#
#  batch_normalization_181 (Batch  (None, 80, 80, 88)  352         ['average_pooling2d_3[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 80, 80, 88)   0           ['batch_normalization_181[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 80, 80, 12)   1056        ['activation_181[0][0]']
#
#  batch_normalization_182 (Batch  (None, 80, 80, 12)  48          ['conv2d_180[0][0]']
#  Normalization)
#
#  activation_182 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_182[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_182[0][0]']
#
#  dropout_92 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_181[0][0]']
#
#  concatenate_88 (Concatenate)   (None, 80, 80, 100)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]']
#
#  batch_normalization_183 (Batch  (None, 80, 80, 100)  400        ['concatenate_88[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 80, 80, 100)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 80, 80, 12)   1200        ['activation_183[0][0]']
#
#  batch_normalization_184 (Batch  (None, 80, 80, 12)  48          ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_184[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_184[0][0]']
#
#  dropout_93 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_183[0][0]']
#
#  concatenate_89 (Concatenate)   (None, 80, 80, 112)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]']
#
#  batch_normalization_185 (Batch  (None, 80, 80, 112)  448        ['concatenate_89[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 80, 80, 112)  0           ['batch_normalization_185[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 80, 80, 12)   1344        ['activation_185[0][0]']
#
#  batch_normalization_186 (Batch  (None, 80, 80, 12)  48          ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_186[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_186[0][0]']
#
#  dropout_94 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_185[0][0]']
#
#  concatenate_90 (Concatenate)   (None, 80, 80, 124)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]']
#
#  batch_normalization_187 (Batch  (None, 80, 80, 124)  496        ['concatenate_90[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 80, 80, 124)  0           ['batch_normalization_187[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 80, 80, 12)   1488        ['activation_187[0][0]']
#
#  batch_normalization_188 (Batch  (None, 80, 80, 12)  48          ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_188[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_188[0][0]']
#
#  dropout_95 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_187[0][0]']
#
#  concatenate_91 (Concatenate)   (None, 80, 80, 136)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]']
#
#  batch_normalization_189 (Batch  (None, 80, 80, 136)  544        ['concatenate_91[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 80, 80, 136)  0           ['batch_normalization_189[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 80, 80, 12)   1632        ['activation_189[0][0]']
#
#  batch_normalization_190 (Batch  (None, 80, 80, 12)  48          ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_190[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_190[0][0]']
#
#  dropout_96 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_189[0][0]']
#
#  concatenate_92 (Concatenate)   (None, 80, 80, 148)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]']
#
#  batch_normalization_191 (Batch  (None, 80, 80, 148)  592        ['concatenate_92[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 80, 80, 148)  0           ['batch_normalization_191[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 80, 80, 12)   1776        ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 80, 80, 12)  48          ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_192[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_192[0][0]']
#
#  dropout_97 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_191[0][0]']
#
#  concatenate_93 (Concatenate)   (None, 80, 80, 160)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]']
#
#  batch_normalization_193 (Batch  (None, 80, 80, 160)  640        ['concatenate_93[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 80, 80, 160)  0           ['batch_normalization_193[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 80, 80, 12)   1920        ['activation_193[0][0]']
#
#  batch_normalization_194 (Batch  (None, 80, 80, 12)  48          ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_194[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_194[0][0]']
#
#  dropout_98 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_193[0][0]']
#
#  concatenate_94 (Concatenate)   (None, 80, 80, 172)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]']
#
#  batch_normalization_195 (Batch  (None, 80, 80, 172)  688        ['concatenate_94[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 80, 80, 172)  0           ['batch_normalization_195[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 80, 80, 12)   2064        ['activation_195[0][0]']
#
#  batch_normalization_196 (Batch  (None, 80, 80, 12)  48          ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_196[0][0]']
#
#  dropout_99 (Dropout)           (None, 80, 80, 12)   0           ['conv2d_195[0][0]']
#
#  concatenate_95 (Concatenate)   (None, 80, 80, 184)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]',
#                                                                   'dropout_99[0][0]']
#
#  batch_normalization_197 (Batch  (None, 80, 80, 184)  736        ['concatenate_95[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 80, 80, 184)  0           ['batch_normalization_197[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 80, 80, 12)   2208        ['activation_197[0][0]']
#
#  batch_normalization_198 (Batch  (None, 80, 80, 12)  48          ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_198 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_198[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_198[0][0]']
#
#  dropout_100 (Dropout)          (None, 80, 80, 12)   0           ['conv2d_197[0][0]']
#
#  concatenate_96 (Concatenate)   (None, 80, 80, 196)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]',
#                                                                   'dropout_99[0][0]',
#                                                                   'dropout_100[0][0]']
#
#  batch_normalization_199 (Batch  (None, 80, 80, 196)  784        ['concatenate_96[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 80, 80, 196)  0           ['batch_normalization_199[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 80, 80, 12)   2352        ['activation_199[0][0]']
#
#  batch_normalization_200 (Batch  (None, 80, 80, 12)  48          ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_200[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_200[0][0]']
#
#  dropout_101 (Dropout)          (None, 80, 80, 12)   0           ['conv2d_199[0][0]']
#
#  concatenate_97 (Concatenate)   (None, 80, 80, 208)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]',
#                                                                   'dropout_99[0][0]',
#                                                                   'dropout_100[0][0]',
#                                                                   'dropout_101[0][0]']
#
#  batch_normalization_201 (Batch  (None, 80, 80, 208)  832        ['concatenate_97[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 80, 80, 208)  0           ['batch_normalization_201[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 80, 80, 12)   2496        ['activation_201[0][0]']
#
#  batch_normalization_202 (Batch  (None, 80, 80, 12)  48          ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_202 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_202[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_202[0][0]']
#
#  dropout_102 (Dropout)          (None, 80, 80, 12)   0           ['conv2d_201[0][0]']
#
#  concatenate_98 (Concatenate)   (None, 80, 80, 220)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]',
#                                                                   'dropout_99[0][0]',
#                                                                   'dropout_100[0][0]',
#                                                                   'dropout_101[0][0]',
#                                                                   'dropout_102[0][0]']
#
#  batch_normalization_203 (Batch  (None, 80, 80, 220)  880        ['concatenate_98[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 80, 80, 220)  0           ['batch_normalization_203[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 80, 80, 12)   2640        ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 80, 80, 12)  48          ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 80, 80, 12)   0           ['batch_normalization_204[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 80, 80, 12)   1296        ['activation_204[0][0]']
#
#  dropout_103 (Dropout)          (None, 80, 80, 12)   0           ['conv2d_203[0][0]']
#
#  concatenate_99 (Concatenate)   (None, 80, 80, 232)  0           ['average_pooling2d_3[0][0]',
#                                                                   'dropout_92[0][0]',
#                                                                   'dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]',
#                                                                   'dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]',
#                                                                   'dropout_99[0][0]',
#                                                                   'dropout_100[0][0]',
#                                                                   'dropout_101[0][0]',
#                                                                   'dropout_102[0][0]',
#                                                                   'dropout_103[0][0]']
#
#  batch_normalization_205 (Batch  (None, 80, 80, 232)  928        ['concatenate_99[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 80, 80, 232)  0           ['batch_normalization_205[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 80, 80, 232)  53824       ['activation_205[0][0]']
#
# ...
#
#  conv2d_330 (Conv2D)            (None, 20, 20, 12)   11712       ['activation_331[0][0]']
#
#  batch_normalization_332 (Batch  (None, 20, 20, 12)  48          ['conv2d_330[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 20, 20, 12)   0           ['batch_normalization_332[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 20, 20, 12)   1296        ['activation_332[0][0]']
#
#  dropout_168 (Dropout)          (None, 20, 20, 12)   0           ['conv2d_331[0][0]']
#
#  concatenate_162 (Concatenate)  (None, 20, 20, 988)  0           ['average_pooling2d_5[0][0]',
#                                                                   'dropout_138[0][0]',
#                                                                   'dropout_139[0][0]',
#                                                                   'dropout_140[0][0]',
#                                                                   'dropout_141[0][0]',
#                                                                   'dropout_142[0][0]',
#                                                                   'dropout_143[0][0]',
#                                                                   'dropout_144[0][0]',
#                                                                   'dropout_145[0][0]',
#                                                                   'dropout_146[0][0]',
#                                                                   'dropout_147[0][0]',
#                                                                   'dropout_148[0][0]',
#                                                                   'dropout_149[0][0]',
#                                                                   'dropout_150[0][0]',
#                                                                   'dropout_151[0][0]',
#                                                                   'dropout_152[0][0]',
#                                                                   'dropout_153[0][0]',
#                                                                   'dropout_154[0][0]',
#                                                                   'dropout_155[0][0]',
#                                                                   'dropout_156[0][0]',
#                                                                   'dropout_157[0][0]',
#                                                                   'dropout_158[0][0]',
#                                                                   'dropout_159[0][0]',
#                                                                   'dropout_160[0][0]',
#                                                                   'dropout_161[0][0]',
#                                                                   'dropout_162[0][0]',
#                                                                   'dropout_163[0][0]',
#                                                                   'dropout_164[0][0]',
#                                                                   'dropout_165[0][0]',
#                                                                   'dropout_166[0][0]',
#                                                                   'dropout_167[0][0]',
#                                                                   'dropout_168[0][0]']
#
#  batch_normalization_333 (Batch  (None, 20, 20, 988)  3952       ['concatenate_162[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 20, 20, 988)  0           ['batch_normalization_333[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 20, 20, 12)   11856       ['activation_333[0][0]']
#
#  batch_normalization_334 (Batch  (None, 20, 20, 12)  48          ['conv2d_332[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 20, 20, 12)   0           ['batch_normalization_334[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 20, 20, 12)   1296        ['activation_334[0][0]']
#
#  dropout_169 (Dropout)          (None, 20, 20, 12)   0           ['conv2d_333[0][0]']
#
#  concatenate_163 (Concatenate)  (None, 20, 20, 1000  0           ['average_pooling2d_5[0][0]',
#                                 )                                 'dropout_138[0][0]',
#                                                                   'dropout_139[0][0]',
#                                                                   'dropout_140[0][0]',
#                                                                   'dropout_141[0][0]',
#                                                                   'dropout_142[0][0]',
#                                                                   'dropout_143[0][0]',
#                                                                   'dropout_144[0][0]',
#                                                                   'dropout_145[0][0]',
#                                                                   'dropout_146[0][0]',
#                                                                   'dropout_147[0][0]',
#                                                                   'dropout_148[0][0]',
#                                                                   'dropout_149[0][0]',
#                                                                   'dropout_150[0][0]',
#                                                                   'dropout_151[0][0]',
#                                                                   'dropout_152[0][0]',
#                                                                   'dropout_153[0][0]',
#                                                                   'dropout_154[0][0]',
#                                                                   'dropout_155[0][0]',
#                                                                   'dropout_156[0][0]',
#                                                                   'dropout_157[0][0]',
#                                                                   'dropout_158[0][0]',
#                                                                   'dropout_159[0][0]',
#                                                                   'dropout_160[0][0]',
#                                                                   'dropout_161[0][0]',
#                                                                   'dropout_162[0][0]',
#                                                                   'dropout_163[0][0]',
#                                                                   'dropout_164[0][0]',
#                                                                   'dropout_165[0][0]',
#                                                                   'dropout_166[0][0]',
#                                                                   'dropout_167[0][0]',
#                                                                   'dropout_168[0][0]',
#                                                                   'dropout_169[0][0]']
#
#  batch_normalization_335 (Batch  (None, 20, 20, 1000  4000       ['concatenate_163[0][0]']
#  Normalization)                 )
#
#  activation_335 (Activation)    (None, 20, 20, 1000  0           ['batch_normalization_335[0][0]']
#                                 )
#
#  global_average_pooling2d_1 (Gl  (None, 1000)        0           ['activation_335[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 1)            1001        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,219,385
# Trainable params: 1,131,217
# Non-trainable params: 88,168
# __________________________________________________________________________________________________
# Start Training
# [Epoch 1/52] [Batch 0/159] [Time: 0:00:43.374225] [all_batchs--> train_epoch_logloss: 5.65333, train_epoch_acc:0.62500]  [this_100_batchs-->train_batchs_logloss: 5.65333, train_batchs_acc:0.62500]
# [Epoch 1/52] [Batch 100/159] [Time: 0:01:58.822603] [all_batchs--> train_epoch_logloss: 5.37366, train_epoch_acc:0.54208]  [this_100_batchs-->train_batchs_logloss: 5.37087, train_batchs_acc:0.54125]
# [Epoch 1/52] [Time: 0:03:10.047813, Total_time: 0:03:10.049648][train_loss_and_acc:5.13952 0.55739] [valid_loss_acc:4.54736 0.51389]
# saving the best model:epoch 1 [4.547361850738525, 0.5138888955116272, 0.5921627680460615, 0.043501041595291]
# [Epoch 2/52] [Batch 0/159] [Time: 0:00:00.760982] [all_batchs--> train_epoch_logloss: 4.46963, train_epoch_acc:0.62500]  [this_100_batchs-->train_batchs_logloss: 4.46963, train_batchs_acc:0.62500]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-440412b2ab44> in <module>()
#     168
#     169 # run_MURA(batch_size= 1, nb_epoch= 3, depth= 22, nb_dense_block= 4, nb_filter= 16, growth_rate= 12, dropout_rate= 0.2, learning_rate=1E-3, weight_decay=1E-4, plot_architecture= False)
# --> 170 run_MURA(batch_size= 8, nb_epoch= 52, depth= 22, nb_dense_block= 4, nb_filter= 16, growth_rate= 12, dropout_rate= 0.2, learning_rate=1E-3, weight_decay=1E-4, plot_architecture= False)
#
# <ipython-input-8-440412b2ab44> in run_MURA(batch_size, nb_epoch, depth, nb_dense_block, nb_filter, growth_rate, dropout_rate, learning_rate, weight_decay, plot_architecture)
#     110             X_batch = data_loader.load_image(Path = X_batch_path, size =im_size)
#     111             Y_batch = np.asarray(Y_batch)
# --> 112             train_logloss, train_acc = model.train_on_batch(X_batch, Y_batch)
#     113
#     114             l_train_loss.append([train_logloss, train_acc])
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1898                                                     class_weight)
#    1899       self.train_function = self.make_train_function()
# -> 1900       logs = self.train_function(iterator)
#    1901
#    1902     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:
